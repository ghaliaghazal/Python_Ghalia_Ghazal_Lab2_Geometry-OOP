# %%
from circle import Circle
from rectangle import Rectangle

# %%
# checking Circle class
circle_1= Circle(0, 0, 1) 
print(circle_1.area)
print(circle_1.perimeter)

circle_2= Circle(2, -1, 1) 
print(circle_2.area)
print(circle_2.perimeter)

print (f"circle area is {circle_1.area} and perimeter is {circle_1.perimeter}")

print (round(circle_2.area, 2))
# Out:
# 3.141592653589793
# 6.283185307179586
# 3.141592653589793
# 6.283185307179586
# circle area is 3.141592653589793 and perimeter is 6.283185307179586
# 3.14

# %%
# checking Rectangle class
rectangle= Rectangle(4, 0, 2, 2) # centrum at (4,0), width 2, height 2
print(rectangle.area)
print(rectangle.perimeter)
print (f"rectangel area is {rectangle.area} and perimeter is {rectangle.perimeter}")
# Out:
# 4
# 8
# rectangel area is 4 and perimeter is 8

# %%
# checking equality
print (circle_1 == circle_2)
print (circle_2 == circle_2)
print (circle_1 == rectangle)
# Out:
# True
# True
# False

# %%
# checking translation
circle_1.translate(5, 3)
circle_1
# Out:
# Circle: radius=1, x=5, y=3

# %%
try:
    circle_1.translate ("Two", 3)
except TypeError as err:
    print (err)
# Out:
# dx must be a number

# %%
try:
    circle_2 = Circle(0, 0, -1)
except TypeError as err:
    print (err)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 try:
# ----> 2     circle_2 = Circle(0, 0, -1)
#       3 except TypeError as err:
#       4     print (err)
#
# File ~/Documents/GitHub/Python_Ghalia_Ghazal_Lab2_Geometry-OOP/Lab2_Task1/circle.py:7, in Circle.__init__(self, x, y, radius)
#       5 def __init__ (self,x=0, y=0, radius=1): #
#       6     super().__init__(x, y)
# ----> 7     self.radius = radius
#
# File ~/Documents/GitHub/Python_Ghalia_Ghazal_Lab2_Geometry-OOP/Lab2_Task1/circle.py:19, in Circle.radius(self, value)
#      17     raise TypeError("Radius must be a number")
#      18 elif value <= 0:
# ---> 19     raise ValueError("Radius must be positive")
#      20 self._radius = value
#
# ValueError: Radius must be positive

# %%
# testa is_unit_circle 
print (circle_1.is_unit_circle())
print (circle_2.is_unit_circle())
# Out:
# False
# False

# %%
# testa is_square
print (rectangle.is_square())
# Out:
# True

# %%
try:
    circle_1.translate ("Two", 3)
except TypeError as err:
    print (err)
# Out:
# dx must be a number

# %%
circle_1.area == circle_2.area
print (circle_1.area == circle_2.area)
# Out:
# True

# %%
circle_1.area == rectangle.area
print (circle_1.area == rectangle.area)
# Out:
# False

# %%
try:
    Circle(0, 0, "-1")
except ValueError as err:
    print (err)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 try:
# ----> 2     Circle(0, 0, "-1")
#       3 except ValueError as err:
#       4     print (err)
#
# File ~/Documents/GitHub/Python_Ghalia_Ghazal_Lab2_Geometry-OOP/Lab2_Task1/circle.py:7, in Circle.__init__(self, x, y, radius)
#       5 def __init__ (self,x=0, y=0, radius=1): #
#       6     super().__init__(x, y)
# ----> 7     self.radius = radius
#
# File ~/Documents/GitHub/Python_Ghalia_Ghazal_Lab2_Geometry-OOP/Lab2_Task1/circle.py:17, in Circle.radius(self, value)
#      14 @radius.setter
#      15 def radius(self, value):
#      16     if not isinstance(value, (int, float)):
# ---> 17         raise TypeError("Radius must be a number")
#      18     elif value <= 0:
#      19         raise ValueError("Radius must be positive")
#
# TypeError: Radius must be a number

# %%
circle3 = Circle(radius=3)
print (circle3.area)
# Out:
# 28.274333882308138

# %%
circle_2 >= circle_1
print (circle_2 >= circle_1)
# Out:
# True

# %%
circle_1
# Out:
# Circle (5, 3 with radius 1)
