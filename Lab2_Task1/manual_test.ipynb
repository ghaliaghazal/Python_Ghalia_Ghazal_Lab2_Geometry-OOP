# %%
from circle import Circle
from rectangle import Rectangle

# %%
circle_1= Circle(0, 0, 1) 
print(circle_1.area)
print(circle_1.perimeter)

circle_2= Circle(2, -1, 1) 
print(circle_2.area)
print(circle_2.perimeter)

print (f"circle area is {circle_1.area} and perimeter is {circle_1.perimeter}")

print (round(circle_2.area, 2))
# Out:
# 3.141592653589793
# 6.283185307179586
# 3.141592653589793
# 6.283185307179586
# circle area is 3.141592653589793 and perimeter is 6.283185307179586
# 3.14

# %%
rectangle= Rectangle(4, 0, 2, 2) # centrum at (4,0), width 2, height 2
print(rectangle.area)
print(rectangle.perimeter)
print (f"rectangel area is {rectangle.area} and perimeter is {rectangle.perimeter}")
# Out:
# 4
# 8
# rectangel area is 4 and perimeter is 8

# %%
print (circle_1 == circle_2)
print (circle_2 == circle_2)
print (circle_1 == rectangle)
# Out:
# True
# True
# False

# %%
circle_1.translate(5, 3)
circle_1
# Out:
# Circle (5, 3 with radius 1)

# %%
circle_1.translate ("Two", 3)
circle_1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 circle_1.translate ("Two", 3)
#       2 circle_1
#
# File ~/Documents/GitHub/Python_Ghalia_Ghazal_Lab2_Geometry-OOP/Lab2_Task1/shape.py:28, in Shape.translate(self, dx, dy)
#      26 def translate (self, dx, dy): # kolla att dx och dy är nummer
#      27     if not isinstance(dx, (int, float)):  # om dx inte är ett nummer, stoppa och ge felmeddelande
# ---> 28         raise TypeError("dx must be a number")
#      30     elif not isinstance(dy, (int, float)): # om dy inte är ett nummer, stoppa och ge felmeddelande
#      31         raise TypeError("dy must be a number")
#
# TypeError: dx must be a number

# %%
circle_2 = Circle(0, 0, -1)
circle_2

# %%
# testa is_unit_circle 
print (circle_1.is_unit_circle())
print (circle_2.is_unit_circle())
# Out:
# False
# False

# %%
# testa is_square
print (rectangle.is_square())
# Out:
# True
