# %%
from circle import Circle
from rectangle import Rectangle

# %%
# checking Circle class

circle_1= Circle (0, 0, 1)
circle_2= Circle (2, -1, 1)
circle_3= Circle (5, 1, 3)

print(circle_1.area)
print(circle_1.perimeter)

print(circle_2.area)
print(circle_2.perimeter)

print (circle_1.area)

print (round(circle_2.area, 2))
# Out:
# 3.141592653589793
# 6.283185307179586
# 3.141592653589793
# 6.283185307179586
# 3.141592653589793
# 3.14

# %%
# checking Rectangle class
rectangle_1= Rectangle(4, 0, 2, 2) # centrum at (4,0), width 2, height 2
rectangle_2= Rectangle(-2, 1, 5, 4)
print(rectangle_1.area)
print(rectangle_1.perimeter)
# Out:
# 4
# 8

# %%
try:
    rectangle_2 = Rectangle(width = 3, height= "7")
except TypeError as err:
    print(err)
# Out:
# height must be a number

# %%
print(f"rectangel area is {rectangle_1.area} and perimeter is {rectangle_1.perimeter}")
# Out:
# rectangel area is 4 and perimeter is 8

# %%
rectangle_1
# Out:
# Rectangle: width=2, height=2, x=4, y=0

# %%
# checking equality
print (circle_1 == circle_2)
print (circle_2 == circle_2)
print (circle_1 == rectangle_1)
# Out:
# True
# True
# False

# %%
# checking translation
circle_1.translate(5, 3) 
circle_1
# Out:
# Circle: radius=1, x=5, y=3

# %%
try:
    circle_1.translate ("Two", 3)
except TypeError as err:
    print (err)
# Out:
# dx must be a number

# %%
# testa is_unit_circle 
print (circle_1.is_unit_circle())
print (circle_2.is_unit_circle())
# Out:
# False
# False

# %%
# testa is_square
print (rectangle_1.is_square())
# Out:
# True

# %%
try:
    circle_1.translate ("Two", 3)
except TypeError as err:
    print (err)
# Out:
# dx must be a number

# %%
circle_1.area == circle_2.area
print (circle_1.area == circle_2.area)
# Out:
# True

# %%
circle_1.area == rectangle_1.area
print (circle_1.area == rectangle_1.area)
# Out:
# False

# %%
try:
    Circle(0, 0, "-1")
except TypeError as err:
    print (err)
# Out:
# Radius must be a number

# %%
circle3 = Circle(radius=3)
print (circle3.area)
# Out:
# 28.274333882308138

# %%
circle_2 >= circle_1
print (circle_2 >= circle_1)
# Out:
# True

# %%
circle_1
# Out:
# Circle: radius=1, x=5, y=3

# %%
print (circle_1)
# Out:
# Circle at (5, 3 with radius 1)

# %%
circle_3 == rectangle_1
# Out:
# False

# %%
try:
    Circle(radius=True)
except TypeError as err:
    print (err)
# Out:
# Radius must be a number

# %%
try:
    Circle(radius=False)
except TypeError as err:
    print (err)
# Out:
# Radius must be a number

# %%
circle_1.area, rectangle_1.area
# Out:
# (3.141592653589793, 4)

# %%
circle_1.translate(-5, -3)

# %%
circle_1.is_unit_circle()
# Out:
# True

# %%
circle_1 >= circle_2 # I got true
circle_1 == circle_2  # I got true
circle_1 <= circle_2 # I got true
circle_1 < circle_2  # I got false
circle_1 > circle_2  # I got false
# Out:
# False
