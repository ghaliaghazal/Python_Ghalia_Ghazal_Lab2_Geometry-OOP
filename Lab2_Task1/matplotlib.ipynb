# %%
import numpy as np  # importerar numpy biblioteket för matematiska operationer
import matplotlib.pyplot as plt  # importerar matplotlib biblioteket för att rita former
plt.xlim(-3,6)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
